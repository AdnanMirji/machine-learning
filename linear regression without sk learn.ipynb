# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv('/content/drive/MyDrive/Task_1/Book1.csv')
print(data)

x=np.array(data[['x']])
y=np.array(data[['y']])
print(x)
print(y)

plt.scatter(x,y)
plt.xlabel("values of x")
plt.ylabel("values of y")
plt.show()
# Out:
#    x  y
# 0  5  9
# 1  6  3
# 2  2  7
# 3  4  5
# 4  8  7
# 5  9  5
# 6  6  4
# [[5]
#  [6]
#  [2]
#  [4]
#  [8]
#  [9]
#  [6]]
# [[9]
#  [3]
#  [7]
#  [5]
#  [7]
#  [5]
#  [4]]

# %%
x_mean=np.mean(x)
y_mean=np.mean(y)
print(x_mean)
print(y_mean)


for i in range(len(x)):
  num+=(x[i]-x_mean)*(y[i]-y_mean)
  den+=(x[i]-x_mean)**2
m=num/den
print("slope=",m)
b=y_mean-(m*x_mean)
print("intercept=",b)
# Out:
# 5.714285714285714
# 5.714285714285714
# slope= [-0.20012203]
# intercept= [6.85784015]

# %%
y_pred=m*x+b
print("predicted values=",y_pred)
# Out:
# predicted values= [[5.85723002]
#  [5.65710799]
#  [6.4575961 ]
#  [6.05735204]
#  [5.25686394]
#  [5.05674192]
#  [5.65710799]]

# %%
plt.scatter(x,y)
plt.plot(x,y_pred)
plt.show()
