# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


data=pd.read_csv('/content/drive/MyDrive/Task_1/Book1.csv')
print(data)

x=np.array(data[['x']])
y=np.array(data[['y']])

print(x)
print(y)

plt.scatter(x,y)
plt.xlabel('independent variable')
plt.ylabel('dependent variable')
plt.show()

alpha=0.01
iterations=1000
m=0
b=0

for i in range(iterations):
  y_pred=m*x+b
  error=y_pred-y

  m=m-alpha*(2/len(y))* np.sum(error*x)
  b=b-alpha*(2/len(y))*np.sum(error)

print("optimized m and b",m,b)

y_predict=m*x+b
plt.scatter(x,y)
plt.plot(x,y_predict)
plt.show()
# Out:
#    x  y
# 0  5  9
# 1  6  3
# 2  2  7
# 3  4  5
# 4  8  7
# 5  9  5
# 6  6  4
# [[5]
#  [6]
#  [2]
#  [4]
#  [8]
#  [9]
#  [6]]
# [[9]
#  [3]
#  [7]
#  [5]
#  [7]
#  [5]
#  [4]]
# optimized m and b -0.11191926714502243 6.284918353461123
